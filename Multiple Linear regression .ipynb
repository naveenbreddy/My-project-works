# %% [markdown]
# # Multiple linear regression modeling using salaries dataset

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
dataset = pd.read_csv('C:\\Users\\nbandagunda\\Desktop\\Python Personal Project\\Machine Learning A-Z (Codes and Datasets)\\Part 2 - Regression\\Section 5 - Multiple Linear Regression\\Python\\50_Startups.csv')
X = dataset.iloc[:, :-1].values
y = dataset.iloc[:, -1].values

# %%
from sklearn.compose import ColumnTransformer
from sklearn.preprocessing import OneHotEncoder
ct = ColumnTransformer(transformers=[('encoder', OneHotEncoder(), [3])], remainder='passthrough')
X = np.array(ct.fit_transform(X))

# %%
#splitting dataset to train and test

from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X,y,test_size=0.2,random_state=101)

# %%
print(X_train)
# Out:
# [[1.0 0.0 0.0 78013.11 121597.55 264346.06]
#  [0.0 0.0 1.0 77044.01 99281.34 140574.81]
#  [0.0 1.0 0.0 130298.13 145530.06 323876.68]
#  [0.0 0.0 1.0 1000.23 124153.04 1903.93]
#  [0.0 1.0 0.0 91749.16 114175.79 294919.57]
#  [0.0 0.0 1.0 144372.41 118671.85 383199.62]
#  [0.0 1.0 0.0 27892.92 84710.77 164470.71]
#  [0.0 1.0 0.0 61994.48 115641.28 91131.24]
#  [0.0 0.0 1.0 114523.61 122616.84 261776.23]
#  [1.0 0.0 0.0 76253.86 113867.3 298664.47]
#  [0.0 0.0 1.0 15505.73 127382.3 35534.17]
#  [0.0 0.0 1.0 20229.59 65947.93 185265.1]
#  [1.0 0.0 0.0 22177.74 154806.14 28334.72]
#  [1.0 0.0 0.0 38558.51 82982.09 174999.3]
#  [0.0 1.0 0.0 101913.08 110594.11 229160.95]
#  [1.0 0.0 0.0 0.0 116983.8 45173.06]
#  [1.0 0.0 0.0 64664.71 139553.16 137962.62]
#  [0.0 1.0 0.0 55493.95 103057.49 214634.81]
#  [0.0 1.0 0.0 28663.76 127056.21 201126.82]
#  [0.0 1.0 0.0 153441.51 101145.55 407934.54]
#  [0.0 0.0 1.0 72107.6 127864.55 353183.81]
#  [1.0 0.0 0.0 46426.07 157693.92 210797.67]
# ...

# %%
print(X_test)
# Out:
# [[1.0 0.0 0.0 44069.95 51283.14 197029.42]
#  [0.0 1.0 0.0 119943.24 156547.42 256512.92]
#  [0.0 0.0 1.0 78389.47 153773.43 299737.29]
#  [1.0 0.0 0.0 63408.86 129219.61 46085.25]
#  [0.0 1.0 0.0 73994.56 122782.75 303319.26]
#  [1.0 0.0 0.0 162597.7 151377.59 443898.53]
#  [0.0 1.0 0.0 75328.87 144135.98 134050.07]
#  [0.0 1.0 0.0 1315.46 115816.21 297114.46]
#  [1.0 0.0 0.0 23640.93 96189.63 148001.11]
#  [1.0 0.0 0.0 0.0 135426.92 0.0]]

# %%
## importing Lin Reg - class

from sklearn.linear_model import LinearRegression

# fitting model

lr=LinearRegression()

# %%
#training the model
lr.fit(X_train,y_train)
# Out:
# LinearRegression()

# %%
#finding the coeff and intercepts

print(lr.coef_)
print(lr.intercept_)
# Out:
# [-1.27991975e+03  1.97192658e+03 -6.92006833e+02  7.79452152e-01
#   2.06811447e-02  3.39226824e-02]
# 46079.903454101324

# %%
##making predictions from the model
y_pred= lr.predict(X_test)

# %%
y_pred= lr.predict(X_test)

print(np.concatenate((y_pred.reshape(len(y_pred),1),y_test.reshape(len(y_test),1)),1))
# Out:
# [[ 86894.76154719  89949.14      ]
#  [153481.03271339 132602.65      ]
#  [119836.84114499 111313.02      ]
#  [ 98459.90083026  97427.84      ]
#  [118555.73979423 110352.25      ]
#  [189726.0015582  191792.06      ]
#  [114295.31485811 105733.54      ]
#  [ 61551.29942222  49490.75      ]
#  [ 70236.86377409  71498.49      ]
#  [ 47600.76743213  42559.73      ]]

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
plt.scatter(y_test,y_pred)

# %%
sns.displot(y_test-y_pred,bins=50)
